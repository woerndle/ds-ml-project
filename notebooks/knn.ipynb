# %% [markdown]
# # KNN Analysis Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# Added path to access preprocessing functions
sys.path.append(os.path.abspath("../src"))

# %% [markdown]
# ## 1. Data Preparation

# %% [markdown]
# ### 1. Traffic Dataset

# %%
from data_processing.preprocess import load_traffic_data

(
    x_train_traffic,
    x_test_traffic,
    y_train_traffic,
    y_test_traffic,
    label_encoder_traffic,
    scaler_traffic
) = load_traffic_data()

display(x_train_traffic)
# Out:
#       CarCount  BikeCount  BusCount  TruckCount     Total  Month  Day  \
# 3758 -1.229900  -0.911105 -0.883897    0.409641 -1.280845    0.0  0.0
# 7970 -1.141506  -0.911105 -0.959224    1.503125 -1.021278    0.0  0.0
# 6995 -0.412252  -0.255889 -0.733242   -1.412832 -0.813624    0.0  0.0
# 7287  0.869466  -0.337791 -0.130621    1.229754  0.812998    0.0  0.0
# 2327 -0.301759  -0.419693 -0.733242   -0.228225 -0.536752    0.0  0.0
# ...        ...        ...       ...         ...       ...    ...  ...
# 1328  0.007621   0.808836  0.020034   -0.410472  0.103514    0.0  0.0
# 8768  1.510325   1.791659  1.827896   -1.321709  1.730136    0.0  0.0
# 228   1.709212   1.382149  1.752569   -1.503956  1.747441    0.0  0.0
# 8317  0.206508   0.645032 -0.582586   -1.503956 -0.121444    0.0  0.0
# 7679 -1.207801  -1.074909 -1.034552   -0.045977 -1.419281    0.0  0.0
#
#       DayOfWeek_Thursday  Day of the week_Friday  Day of the week_Monday  ...  \
# 3758                True                   False                   False  ...
# 7970                True                   False                   False  ...
# 6995                True                    True                   False  ...
# 7287                True                   False                    True  ...
# 2327                True                    True                   False  ...
# ...                  ...                     ...                     ...  ...
# 1328                True                   False                    True  ...
# 8768                True                   False                   False  ...
# 228                 True                   False                   False  ...
# 8317                True                    True                   False  ...
# 7679                True                    True                   False  ...
#
#       Time_14  Time_15  Time_16  Time_17  Time_18  Time_19  Time_20  Time_21  \
# 3758    False    False    False    False    False    False    False    False
# 7970    False    False    False    False    False    False    False    False
# 6995    False    False    False    False    False    False     True    False
# 7287    False    False    False    False    False    False    False     True
# 2327    False    False    False    False    False    False    False    False
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1328    False    False    False    False    False    False     True    False
# 8768    False    False    False    False    False    False    False    False
# 228     False    False    False    False    False    False    False    False
# 8317    False     True    False    False    False    False    False    False
# 7679    False    False    False    False    False    False    False    False
#
#       Time_22  Time_23
# 3758    False    False
# 7970    False    False
# 6995    False    False
# 7287    False    False
# 2327    False    False
# ...       ...      ...
# 1328    False    False
# 8768    False    False
# 228     False    False
# 8317    False    False
# 7679    False     True
#
# [6249 rows x 39 columns]

# %% [markdown]
# ### 2. Congressional Voting

# %%
from data_processing.preprocess import load_congressional_voting_data

(
    x_train_voting,
    x_test_voting,
    y_train_voting,
    y_test_voting,
    label_encoder_voting,
    scaler_voting
) = load_congressional_voting_data()

display(x_train_voting)
# Out:
#      handicapped-infants  water-project-cost-sharing  \
# 202            -0.911770                    0.818737
# 73             -0.911770                   -1.221394
# 22             -0.911770                   -1.221394
# 31              1.096767                    0.818737
# 41             -0.911770                   -1.221394
# ..                   ...                         ...
# 200             1.096767                    0.818737
# 212             1.096767                    0.818737
# 197            -0.911770                   -1.221394
# 122            -0.911770                   -1.221394
# 63             -0.911770                    0.818737
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 202                          -1.204829              1.156919              1.0
# 73                           -1.204829              1.156919              1.0
# 22                           -1.204829             -0.864365             -1.0
# 31                            0.829993             -0.864365             -1.0
# 41                            0.829993             -0.864365             -1.0
# ..                                 ...                   ...              ...
# 200                           0.829993             -0.864365             -1.0
# 212                           0.829993             -0.864365             -1.0
# 197                          -1.204829              1.156919              1.0
# 122                          -1.204829              1.156919              1.0
# 63                            0.829993              1.156919              1.0
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 202                      0.72111                -1.188570
# 73                      -1.38675                -1.188570
# 22                      -1.38675                 0.841347
# 31                      -1.38675                 0.841347
# 41                       0.72111                 0.841347
# ..                           ...                      ...
# 200                     -1.38675                 0.841347
# 212                     -1.38675                 0.841347
# 197                      0.72111                -1.188570
# 122                      0.72111                 0.841347
# 63                       0.72111                 0.841347
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 202                  -1.273063   -0.948683     1.082326
# 73                   -1.273063   -0.948683    -0.923936
# 22                    0.785507    1.054093     1.082326
# 31                    0.785507   -0.948683     1.082326
# 41                    0.785507    1.054093    -0.923936
# ..                         ...         ...          ...
# 200                   0.785507    1.054093    -0.923936
# 212                   0.785507    1.054093    -0.923936
# 197                  -1.273063   -0.948683    -0.923936
# 122                  -1.273063   -0.948683     1.082326
# 63                    0.785507   -0.948683    -0.923936
#
#      synfuels-crporation-cutback  education-spending  superfund-right-to-sue  \
# 202                     1.366720            1.221394                0.887826
# 73                     -0.731679            1.221394               -1.126347
# 22                     -0.731679            1.221394                0.887826
# 31                     -0.731679           -0.818737               -1.126347
# 41                     -0.731679           -0.818737               -1.126347
# ..                           ...                 ...                     ...
# 200                     1.366720           -0.818737               -1.126347
# 212                     1.366720           -0.818737               -1.126347
# 197                    -0.731679            1.221394                0.887826
# 122                    -0.731679            1.221394               -1.126347
# 63                     -0.731679           -0.818737                0.887826
#
#         crime  duty-free-exports  export-administration-act-south-africa
# 202 -1.204829          -0.864365                                0.422249
# 73   0.829993          -0.864365                               -2.368268
# 22   0.829993           1.156919                                0.422249
# 31  -1.204829          -0.864365                                0.422249
# 41  -1.204829           1.156919                                0.422249
# ..        ...                ...                                     ...
# 200 -1.204829           1.156919                                0.422249
# 212 -1.204829           1.156919                                0.422249
# 197  0.829993          -0.864365                               -2.368268
# 122  0.829993           1.156919                                0.422249
# 63   0.829993           1.156919                                0.422249
#
# [152 rows x 16 columns]
